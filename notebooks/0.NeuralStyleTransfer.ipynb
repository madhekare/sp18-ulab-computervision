# %% [markdown]
# # Style Transfer Demo

# %% [markdown]
# The goal of this semester is to:
#
# * Understand the state of the art in Style Transfer
# * Develop skills and tools necessary to do so
#
# This notebook, [inspired by this repo](https://github.com/leongatys/PytorchNeuralStyleTransfer), will be a quick glance into the internals of the original Style Transfer implementation.
#
# Don't worry if you don't know what's going on!

# %% [markdown]
# <table>
#     <tr>
#     <td> <img src="./Images/vangogh_starry_night.jpg" alt="Drawing" style="width: 50px;"/> </td>
#     <td> <img src="./Images/Tuebingen_Neckarfront.jpg" alt="Drawing" style="width: 50px;"/> </td>
#     </tr>
# </table>

# %%
# %pylab inline
import time
import os 
image_dir = os.getcwd() + '/Images/'
model_dir = os.getcwd() + '/Models/'

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

import torchvision
from torchvision import transforms

from PIL import Image
from collections import OrderedDict
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Download a pre-trained image classification weights

# %%
assert not os.path.exists("./Models/vgg_conv.pth"), "Not redownloading vgg..."
# !brew install wget
# !mkdir Models || true && cd Models && wget -c --no-check-certificate https://bethgelab.org/media/uploads/pytorch_models/vgg_conv.pth && cd ..
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core, caskroom/cask).
# ==> New Formulae
# amber                      hlint                      ocrmypdf
# augustus                   hmmer                      octomap
# autopep8                   howdoi                     odpi
# ballerina                  hss                        openimageio
# bareos-client              icemon                     plank
# boost-python3              jdupes                     posh
# caffe                      krakend                    primer3
# calicoctl                  kube-ps1                   python@2
# chrome-export              libbi                      qtkeychain
# clblast                    libbitcoin-consensus       restview
# console_bridge             libccd                     shelltestrunner
# container-diff             libdill                    shogun
# coreos-ct                  libjwt                     siril
# dartsim                    libomp                     skaffold
# dashing                    libsbol                    skafos
# docker-squash              libserialport              srt
# dynare                     llvm@5                     stellar-core
# fastme                     lzfse                      terraforming
# fcl                        mafft                      tmux-xpanes
# fruit                      mariadb-connector-odbc     tomcat@8
# futhark                    maxwell                    unravel
# git-sizer                  mdcat                      urdfdom
# go-bindata                 mill                       urdfdom_headers
# go@1.9                     mmseqs2                    vis
# gocryptfs                  mpir                       webtorrent-cli
# gpredict                   neomutt                    zig
# grv                        nyx
# ==> Updated Formulae
# git ✔                                    libebur128
# sqlite ✔                                 libepoxy
# abcde                                    libgaiagraphics
# abcm2ps                                  libgee
# abcmidi                                  libgeotiff
# abnfgen                                  libgosu
# acmetool                                 libgtop
# acpica                                   libhttpseverywhere
# advancecomp                              libical
# advancemame                              liblwgeom
# agedu                                    libmaxminddb
# akamai                                   libmicrohttpd
# allure                                   libmonome
# alot                                     libmpdclient
# amazon-ecs-cli                           libmspub
# ammonite-repl                            libphonenumber
# angular-cli                              libpq
# ansible                                  libpqxx
# ansible-cmdb                             libqalculate
# ansible-lint                             librasterlite
# ansifilter                               libraw
# ant                                      libre
# apache-geode                             librealsense
# apache-spark                             librsvg
# apibuilder-cli                           librsync
# apm-server                               libsass
# app-engine-java                          libsigsegv
# app-engine-python                        libspatialite
# aqbanking                                libstrophe
# arangodb                                 libtasn1
# argyll-cms                               libtensorflow
# armadillo                                libtiff
# armor                                    libtomcrypt
# artifactory                              libtrace
# asciinema                                libtrng
# asdf                                     libu2f-host
# astyle                                   libunistring
# atdtool                                  libupnp
# ats2-postiats                            libuv
# auditbeat                                libvirt
# augeas                                   libvpx
# autogen                                  libwebsockets
# automake                                 libxlsxwriter
# aws-elasticbeanstalk                     libzip
# aws-sdk-cpp                              libzzip
# awscli                                   linkerd
# azure-cli                                liquibase
# babl                                     llnode
# backupninja                              llvm
# bam                                      lnav
# bandcamp-dl                              log4cplus
# baresip                                  logentries
# bartycrouch                              logrotate
# bash                                     logstalgia
# bash-preexec                             logstash
# bash-snippets                            lorem
# bazel                                    lumo
# bcftools                                 lynis
# bdw-gc                                   lysp
# bedops                                   lzip
# bee                                      lzlib
# bench                                    macvim
# bfg                                      magic-wormhole
# bigloo                                   makensis
# binaryen                                 mame
# bind                                     mapnik
# binutils                                 mapserver
# biogeme                                  mariadb
# bit                                      mariadb-connector-c
# bitcoin                                  mariadb@10.0
# bitrise                                  mariadb@10.1
# blast                                    mas
# blueutil                                 masscan
# bmake                                    maven
# boost-python                             mbedtls
# bork                                     memcached
# bowtie2                                  mercurial
# braid                                    meson
# brew-gem                                 metabase
# bro                                      metricbeat
# brotli                                   mgba
# btfs                                     micro
# buildapp                                 micropython
# buku                                     mikutter
# burp                                     mingw-w64
# byteman                                  minimal-racket
# bzt                                      minio-mc
# c-ares                                   minisign
# caddy                                    miniupnpc
# caf                                      mitmproxy
# cake                                     mkdocs
# calabash                                 mkvtoolnix
# calc                                     mlt
# camlp5                                   mlton
# cargo-completion                         mockserver
# carthage                                 modules
# cask                                     molecule
# cassandra                                monetdb
# castxml                                  mongo-c-driver
# cayley                                   mongo-cxx-driver
# cc65                                     mongodb
# ccache                                   mongodb@3.0
# ccm                                      mongodb@3.2
# certbot                                  mongodb@3.4
# certigo                                  mongoose
# cfengine                                 mp3gain
# cfitsio                                  mpc
# cfr-decompiler                           mpd
# cfssl                                    mpdas
# cgal                                     mpfr
# cgrep                                    mps-youtube
# chakra                                   mpv
# chamber                                  mrboom
# charm-tools                              mruby
# checkstyle                               mu
# chibi-scheme                             multimarkdown
# chisel                                   mutt
# chocolate-doom                           mypy
# chromaprint                              mysql
# chromedriver                             mysql@5.5
# chronograf                               mysql@5.6
# chuck                                    mytop
# cimg                                     nailgun
# citus                                    nano
# cjdns                                    nanopb-generator
# ckan                                     nasm
# clamav                                   ncdu
# clang-format                             nco
# clhep                                    ncurses
# cloc                                     neko
# clojure                                  neovim
# cloog                                    netcdf
# closure-compiler                         netpbm
# cmake                                    nghttp2
# cockatrice                               nginx
# cockroach                                nicotine-plus
# cocoapods                                nim
# coffeescript                             nnn
# collector-sidecar                        node
# compcert                                 node-build
# conan                                    node@4
# conjure-up                               node@6
# consul                                   node@8
# consul-backinator                        nq
# coq                                      nsd
# corebird                                 nspr
# cppad                                    nss
# cppcheck                                 nuget
# cppcms                                   numpy
# cpprestsdk                               ocaml
# cracklib                                 ocaml-num
# creduce                                  ocamlsdl
# cromwell                                 octave
# crowdin                                  ode
# cryfs                                    offlineimap
# cryptopp                                 onetime
# crystal-icr                              oniguruma
# crystal-lang                             ooniprobe
# csvkit                                   opencoarrays
# csvtomd                                  opencv
# ctop                                     opencv@2
# curl                                     opendetex
# cvs2svn                                  openrct2
# daemonize                                openrtsp
# darksky-weather                          openshift-cli
# dateutils                                openvpn
# davmail                                  orc-tools
# dbhash                                   ortp
# dbus                                     osm2pgrouting
# dbus-glib                                osm2pgsql
# dcmtk                                    osquery
# dcos-cli                                 overmind
# ddgr                                     owfs
# ddrescue                                 p11-kit
# dep                                      p7zip
# dependency-check                         packer
# dfmt                                     packetbeat
# dhall-json                               paket
# diamond                                  pandoc
# diffoscope                               pandoc-citeproc
# diffuse                                  pandoc-crossref
# digdag                                   par2
# direnv                                   parallel
# dislocker                                passenger
# distcc                                   pastebinit
# django-completion                        pc6001vx
# dlib                                     pcb
# dmd                                      pdal
# dnscrypt-proxy                           pdns
# dnscrypt-wrapper                         pdnsrec
# docfx                                    pegtl
# docker                                   percona-server
# docker-completion                        percona-server@5.6
# docker-compose                           percona-toolkit
# docker-compose-completion                percona-xtrabackup
# docker-gen                               pgcli
# docker-machine                           pgformatter
# docker-machine-completion                pgloader
# doctl                                    pgpool-ii
# dovecot                                  pgroonga
# dpkg                                     phoronix-test-suite
# dropbear                                 picard-tools
# dscanner                                 picocom
# dssim                                    pilosa
# dtc                                      pinentry
# dub                                      pioneer
# duck                                     pipenv
# duo_unix                                 pjproject
# duplicity                                planck
# duply                                    plantuml
# dwarfutils                               platformio
# e2fsprogs                                plzip
# ebook-tools                              pmd
# ecl                                      pngquant
# efl                                      poco
# elasticsearch                            ponysay
# elasticsearch@5.6                        postgis
# elektra                                  postgresql
# elixir                                   postgresql@9.4
# elvish                                   postgresql@9.5
# emacs-clang-complete-async               postgresql@9.6
# embulk                                   pre-commit
# emscripten                               presto
# encfs                                    prips
# enchant                                  proguard
# entr                                     proj
# envconsul                                prometheus
# eralchemy                                protobuf
# erlang                                   pspg
# etcd                                     pwntools
# etsh                                     py2cairo
# exempi                                   py3cairo
# exiftool                                 pybind11
# exim                                     pyenv
# expect                                   pyinvoke
# f3                                       pyqt
# faas-cli                                 python
# fabio                                    python-markdown
# fades                                    pytouhou
# fail2ban                                 qemu
# fb-client                                qpdf
# fbi-servefiles                           qpid-proton
# fd                                       qscintilla2
# fdclone                                  qt
# fdroidserver                             quantlib
# feedgnuplot                              questdb
# feh                                      quicktype
# fetch-crl                                rabbitmq
# ffmbc                                    radare2
# ffmpeg                                   rakudo-star
# ffmpeg@2.8                               ranger
# fibjs                                    re2
# filebeat                                 recon-ng
# fio                                      redex
# firebase-cli                             redis
# fizmo                                    restic
# flatcc                                   rgbds
# flow                                     riemann
# fltk                                     ripgrep
# fluent-bit                               rkhunter
# fluid-synth                              rocksdb
# flyway                                   rom-tools
# fn                                       root
# folly                                    roswell
# fonttools                                rpm
# forego                                   rst-lint
# format-udf                               rsync
# fossil                                   rtags
# fox                                      rtv
# freeciv                                  ruby
# freedink                                 ruby-build
# freeipmi                                 ruby@1.8
# freeradius-server                        ruby@2.0
# freeswitch                               ruby@2.2
# freetds                                  ruby@2.3
# freexl                                   rust
# fribidi                                  rustup-init
# frugal                                   s-nail
# fuego                                    s-search
# fuse-emulator                            s3-backer
# fuse-zip                                 sagittarius-scheme
# fwup                                     saldl
# g3log                                    saltstack
# gammaray                                 samtools
# gawk                                     sane-backends
# gcc                                      sassc
# gcc@4.9                                  saxon
# gcc@5                                    sbcl
# gcovr                                    sbt
# gdal                                     sbt@0.13
# gdb                                      sbtenv
# gdnsd                                    scala@2.10
# gecode                                   scamper
# geeqie                                   sccache
# gegl                                     sceptre
# geoip                                    schismtracker
# geoserver                                scipy
# get-flash-videos                         scummvm
# getdns                                   scummvm-tools
# geth                                     sdl2
# getmail                                  sdl2_image
# gexiv2                                   selecta
# gforth                                   selenium-server-standalone
# gifski                                   serialosc
# gimme                                    sfk
# ginac                                    shadowsocks-libev
# git-annex                                shfmt
# git-archive-all                          shyaml
# git-cola                                 simg2img
# git-extras                               simgrid
# git-fresh                                singular
# git-ftp                                  sip
# git-imerge                               sjk
# git-lfs                                  sleuthkit
# git-recent                               snakemake
# git-standup                              snapcraft
# git-town                                 snappystream
# gitbucket                                sngrep
# github-keygen                            socat
# gitlab-runner                            solr
# gitless                                  sonarqube
# gjs                                      sops
# glade                                    sound-touch
# glbinding                                source-to-image
# glib-openssl                             sourcekitten
# global                                   sourcery
# glpk                                     sparkey
# gmt                                      spatialite-gui
# gnatsd                                   spatialite-tools
# gnome-autoar                             speech-tools
# gnome-recipes                            speedtest-cli
# gnu-cobol                                sphinx-doc
# gnupg                                    spigot
# gnutls                                   spin
# go                                       spotbugs
# go-jira                                  sqldiff
# go@1.8                                   sqlite-analyzer
# gobject-introspection                    sqlmap
# gobuster                                 sratoolkit
# godep                                    sslh
# goenv                                    sslsplit
# gollum                                   sslyze
# gom                                      sstp-client
# gomplate                                 statik
# googler                                  stella
# gopass                                   stk
# gosu                                     stlink
# gource                                   stockfish
# gpatch                                   stone-soup
# gradle                                   storm
# grafana                                  streamlink
# grails                                   stress-ng
# grakn                                    strongswan
# graphene                                 stubby
# graphicsmagick                           subversion
# grc                                      subversion@1.8
# gromacs                                  superlu
# groonga                                  supervisor
# groovy                                   surfraw
# grpc                                     suricata
# gsoap                                    svgcleaner
# gst-python                               svgo
# gtk+                                     svtplay-dl
# gtk+3                                    swagger-codegen
# guile                                    swift-protobuf
# guile@2.0                                swiftformat
# gutenberg                                swiftlint
# gwenhywfar                               sword
# gwt                                      sylpheed
# gwyddion                                 syncthing
# gxml                                     sysbench
# hadolint                                 sysdig
# hadoop                                   systemc
# hana                                     szip
# haproxy                                  taisei
# harfbuzz                                 tarantool
# hashcat                                  telegraf
# haskell-stack                            teleport
# hatari                                   terminator
# haxe                                     termius
# hayai                                    terraform
# heartbeat                                terragrunt
# help2man                                 testssl
# heroku                                   texmath
# hg-fast-export                           thefuck
# highlight                                tig
# hostess                                  tile38
# html-xml-utils                           timewarrior
# htmldoc                                  tin
# htop                                     tintin
# htslib                                   tippecanoe
# http-parser                              titlecase
# httpd                                    tldr
# httpie                                   todoman
# hubflow                                  tokei
# huexpress                                tomcat
# hugo                                     tomee-webprofile
# hwloc                                    tor
# hyperscan                                tracebox
# i2p                                      traefik
# ibex                                     transmission
# ice                                      ttf2eot
# icoutils                                 ttyd
# ideviceinstaller                         twarc
# idnits                                   twine-pypi
# igv                                      twoping
# imagemagick                              twtxt
# imagemagick@6                            txr
# imagesnap                                typescript
# infer                                    ucon64
# influxdb                                 udpxy
# innotop                                  udunits
# inspectrum                               uhd
# iperf3                                   unbound
# ipython                                  unibilium
# ipython@5                                unison
# iron-functions                           unixodbc
# irssi                                    urh
# isc-dhcp                                 uriparser
# iso-codes                                userspace-rcu
# javarepl                                 uwsgi
# jbake                                    vagrant-completion
# jenkins                                  vala
# jenkins-job-builder                      vapoursynth
# jenkins-lts                              vault
# jetty                                    vdirsyncer
# jetty-runner                             verilator
# jfrog-cli-go                             vert.x
# jhiccup                                  viewvc
# jhipster                                 vifm
# jmeter                                   vim
# jmxtrans                                 vim@7.4
# jnettop                                  vips
# joplin                                   vnstat
# jpeg                                     w3m
# jruby                                    webpack
# juju                                     wget
# juju-wait                                whatmp3
# jupyter                                  whohas
# just                                     whois
# jvgrep                                   wiggle
# jvm-mon                                  wine
# kaitai-struct-compiler                   winetricks
# kallisto                                 wiredtiger
# kedge                                    wireguard-tools
# keepassc                                 wireshark
# kerl                                     woboq_codebrowser
# khal                                     wpcli-completion
# khard                                    wpscan
# kibana                                   wrk
# kibana@5.6                               wtf
# kitchen-sync                             wwwoffle
# kite                                     wxmaxima
# knot                                     x264
# knot-resolver                            x265
# kobalt                                   x3270
# kompose                                  xdot
# kontena                                  xerces-c
# kops                                     xmake
# kotlin                                   xml-tooling-c
# kubeless                                 xmrig
# kubernetes-cli                           xonsh
# kubernetes-helm                          xpdf
# lame                                     xrootd
# landscaper                               xtensor
# latex2html                               xvid
# lbdb                                     xxhash
# ldc                                      yaml-cpp
# ldns                                     yara
# lean-cli                                 yarn
# leaps                                    yaze-ag
# ledit                                    ykman
# lensfun                                  ykneomgr
# leptonica                                ykpers
# less                                     yle-dl
# libav                                    yosys
# libbitcoin                               you-get
# libbitcoin-blockchain                    youtube-dl
# libbitcoin-database                      zabbix
# libbitcoin-explorer                      zanata-client
# libbitcoin-node                          zile
# libbitcoin-server                        zim
# libcouchbase                             zimg
# libdvdnav                                zint
# libdvdread                               zsh-lovers
# ==> Renamed Formulae
# php72 -> php               ssreflect -> math-comp     tachyon -> alluxio
# ==> Deleted Formulae
# python3 ✔                                juju@1.25
# antlr@3                                  kubernetes-cli@1.3
# apache-spark@1.5                         laszip@2
# apache-spark@1.6                         ledger@2.6
# autoconf@2.64                            libmpc@0.8
# automake@1.12                            libpng@1.2
# azure-cli@1                              libpqxx@3
# bazel@0.2                                librealsense@1
# clang-format@3.8                         libxml2@2.7
# cloog@0.15                               llvm@3.8
# clozure-cl                               logstash@2.4
# docker@1.11                              logstash@5.6
# docker@1.71                              mg3a
# eigen@3.2                                moodbar
# gcc@4.6                                  mpfr@2
# gcc@4.7                                  mvptree
# gcc@4.8                                  open-mpi@1.6
# glfw@2                                   pcap_dnsproxy
# gmp@4                                    percona-server@5.5
# go@1.5                                   perl@5.14
# go@1.6                                   ppl@0.11
# go@1.7                                   qt@5.7
# grails@2.5                               redis@2.6
# gsl@1                                    root@5
# gst-plugins-bad@0.10                     ruby@1.9
# gst-plugins-base@0.10                    ruby@2.1
# gst-plugins-good@0.10                    selenium-server-standalone@2.45
# gst-plugins-ugly@0.10                    srtp@1.6
# gstreamer@0.10                           swig@2
# influxdb@0.8                             talk-filters
# isl@0.11                                 tomcat@8.0
# isl@0.12                                 unison@2.40
# isl@0.14                                 zeromq@3.2
# jetty@8                                  zeromq@4.0
# jpeg@6                                   zeromq@4.1
# ==> Processing python3 formula rename to python
# ==> Unlinking python3
# ==> Moving python3 versions to /usr/local/Cellar/python
# ==> Relinking python
# Warning: python is outdated!
# To avoid broken installations, as soon as possible please run:
#   brew upgrade
# Or, if you're OK with a less reliable fix:
#   brew upgrade python
#
# ==> Installing dependencies for wget: gettext, libunistring, libidn2
# ==> Installing wget dependency: gettext
# ==> Downloading https://homebrew.bintray.com/bottles/gettext-0.19.8.1.high_sierr
# ######################################################################## 100.0%
# ==> Pouring gettext-0.19.8.1.high_sierra.bottle.tar.gz
# ==> Caveats
# This formula is keg-only, which means it was not symlinked into /usr/local,
# because macOS provides the BSD gettext library & some software gets confused if both are in the library path.
#
# If you need to have this software first in your PATH run:
#   echo 'export PATH="/usr/local/opt/gettext/bin:$PATH"' >> ~/.bash_profile
#
# For compilers to find this software you may need to set:
#     LDFLAGS:  -L/usr/local/opt/gettext/lib
#     CPPFLAGS: -I/usr/local/opt/gettext/include
#
# ==> Summary
# 🍺  /usr/local/Cellar/gettext/0.19.8.1: 1,935 files, 16.9MB
# ==> Installing wget dependency: libunistring
# ==> Downloading https://homebrew.bintray.com/bottles/libunistring-0.9.9.high_sie
# ######################################################################## 100.0%
# ==> Pouring libunistring-0.9.9.high_sierra.bottle.tar.gz
# 🍺  /usr/local/Cellar/libunistring/0.9.9: 54 files, 4.4MB
# ==> Installing wget dependency: libidn2
# ==> Downloading https://homebrew.bintray.com/bottles/libidn2-2.0.4.high_sierra.b
# ######################################################################## 100.0%
# ==> Pouring libidn2-2.0.4.high_sierra.bottle.tar.gz
# 🍺  /usr/local/Cellar/libidn2/2.0.4: 46 files, 580.6KB
# ==> Installing wget
# ==> Downloading https://homebrew.bintray.com/bottles/wget-1.19.4_1.high_sierra.b
# ######################################################################## 100.0%
# ==> Pouring wget-1.19.4_1.high_sierra.bottle.tar.gz
# 🍺  /usr/local/Cellar/wget/1.19.4_1: 50 files, 3.7MB
# mkdir: Models: File exists
# --2018-03-10 17:52:04--  https://bethgelab.org/media/uploads/pytorch_models/vgg_conv.pth
# Resolving bethgelab.org (bethgelab.org)... 46.38.232.246
# Connecting to bethgelab.org (bethgelab.org)|46.38.232.246|:443... connected.
# WARNING: cannot verify bethgelab.org's certificate, issued by ‘emailAddress=webmaster@bethgelab.org,CN=bethgelab.org,OU=Computational Vision and Neuroscience,O=University of Tuebingen\\, CIN,L=Tuebingen,ST=Baden-Wuerttemberg,C=DE’:
#   Self-signed certificate encountered.
# HTTP request sent, awaiting response... 200 OK
# Length: 160198540 (153M) [text/plain]
# Saving to: ‘vgg_conv.pth’
#
# vgg_conv.pth        100%[===================>] 152.78M  1.91MB/s    in 1m 44s
#
# 2018-03-10 17:53:48 (1.47 MB/s) - ‘vgg_conv.pth’ saved [160198540/160198540]

# %% [markdown]
# #### Define placeholders to put weights in a way that conveniently lets you grab the outputs from any layer

# %%
class VGG(nn.Module):
    def __init__(self, pool='max'):
        super(VGG, self).__init__()
        #vgg modules
        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv3_4 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv4_4 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_4 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        if pool == 'max':
            self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
            self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
            self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
            self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)
            self.pool5 = nn.MaxPool2d(kernel_size=2, stride=2)
        elif pool == 'avg':
            self.pool1 = nn.AvgPool2d(kernel_size=2, stride=2)
            self.pool2 = nn.AvgPool2d(kernel_size=2, stride=2)
            self.pool3 = nn.AvgPool2d(kernel_size=2, stride=2)
            self.pool4 = nn.AvgPool2d(kernel_size=2, stride=2)
            self.pool5 = nn.AvgPool2d(kernel_size=2, stride=2)
            
    def forward(self, x, out_keys):
        out = {}
        out['r11'] = F.relu(self.conv1_1(x))
        out['r12'] = F.relu(self.conv1_2(out['r11']))
        out['p1'] = self.pool1(out['r12'])
        out['r21'] = F.relu(self.conv2_1(out['p1']))
        out['r22'] = F.relu(self.conv2_2(out['r21']))
        out['p2'] = self.pool2(out['r22'])
        out['r31'] = F.relu(self.conv3_1(out['p2']))
        out['r32'] = F.relu(self.conv3_2(out['r31']))
        out['r33'] = F.relu(self.conv3_3(out['r32']))
        out['r34'] = F.relu(self.conv3_4(out['r33']))
        out['p3'] = self.pool3(out['r34'])
        out['r41'] = F.relu(self.conv4_1(out['p3']))
        out['r42'] = F.relu(self.conv4_2(out['r41']))
        out['r43'] = F.relu(self.conv4_3(out['r42']))
        out['r44'] = F.relu(self.conv4_4(out['r43']))
        out['p4'] = self.pool4(out['r44'])
        out['r51'] = F.relu(self.conv5_1(out['p4']))
        out['r52'] = F.relu(self.conv5_2(out['r51']))
        out['r53'] = F.relu(self.conv5_3(out['r52']))
        out['r54'] = F.relu(self.conv5_4(out['r53']))
        out['p5'] = self.pool5(out['r54'])
        return [out[key] for key in out_keys]

# %% [markdown]
# #### Load the weights into the placeholders

# %%
vgg = VGG()
vgg.load_state_dict(torch.load(model_dir + 'vgg_conv.pth'))
for param in vgg.parameters():
    param.requires_grad = False
if torch.cuda.is_available():
    vgg.cuda()

# %%
# gram matrix and loss
class GramMatrix(nn.Module):
    def forward(self, input):
        b,c,h,w = input.size()
        F = input.view(b, c, h*w)
        G = torch.bmm(F, F.transpose(1,2)) 
        G.div_(h*w)
        return G

class GramMSELoss(nn.Module):
    def forward(self, input, target):
        out = nn.MSELoss()(GramMatrix()(input), target)
        return(out)

# %% [markdown]
# ### Setup pre and post processing for images

# %%
img_size = 512 
prep = transforms.Compose([transforms.Scale(img_size),
                           transforms.ToTensor(),
                           transforms.Lambda(lambda x: x[torch.LongTensor([2,1,0])]), #turn to BGR
                           transforms.Normalize(mean=[0.40760392, 0.45795686, 0.48501961], #subtract imagenet mean
                                                std=[1,1,1]),
                           transforms.Lambda(lambda x: x.mul_(255)),
                          ])
postpa = transforms.Compose([transforms.Lambda(lambda x: x.mul_(1./255)),
                           transforms.Normalize(mean=[-0.40760392, -0.45795686, -0.48501961], #add imagenet mean
                                                std=[1,1,1]),
                           transforms.Lambda(lambda x: x[torch.LongTensor([2,1,0])]), #turn to RGB
                           ])
postpb = transforms.Compose([transforms.ToPILImage()])
def postp(tensor): # to clip results in the range [0,1]
    t = postpa(tensor)
    t[t>1] = 1    
    t[t<0] = 0
    img = postpb(t)
    return img
# Out:
# /Users/emadhekar/anaconda/envs/ulab/lib/python3.6/site-packages/torchvision-0.2.0-py3.6.egg/torchvision/transforms/transforms.py:156: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.

# %%
#load images, ordered as [style_image, content_image]
img_dirs = [image_dir, image_dir]
img_names = ['vangogh_starry_night.jpg', 'Tuebingen_Neckarfront.jpg']
imgs = [Image.open(img_dirs[i] + name) for i,name in enumerate(img_names)]
imgs_torch = [prep(img) for img in imgs]
if torch.cuda.is_available():
    imgs_torch = [Variable(img.unsqueeze(0).cuda()) for img in imgs_torch]
else:
    imgs_torch = [Variable(img.unsqueeze(0)) for img in imgs_torch]
style_image, content_image = imgs_torch

# opt_img = Variable(torch.randn(content_image.size()).type_as(content_image.data), requires_grad=True) #random init
opt_img = Variable(content_image.data.clone(), requires_grad=True)

# %% [markdown]
# ### Define layers, loss functions, weights and compute optimization targets

# %%
style_layers = ['r11','r21','r31','r41', 'r51'] 
content_layers = ['r42']
loss_layers = style_layers + content_layers
loss_fns = [GramMSELoss()] * len(style_layers) + [nn.MSELoss()] * len(content_layers)
if torch.cuda.is_available():
    loss_fns = [loss_fn.cuda() for loss_fn in loss_fns]
    
#these are good weights settings:
style_weights = [1e3/n**2 for n in [64,128,256,512,512]]
content_weights = [1e0]
weights = style_weights + content_weights

#compute optimization targets
style_targets = [GramMatrix()(A).detach() for A in vgg(style_image, style_layers)]
content_targets = [A.detach() for A in vgg(content_image, content_layers)]
targets = style_targets + content_targets

# %% [markdown]
# ### Run style transfer

# %%
max_iter = 50
show_iter = 2
optimizer = optim.LBFGS([opt_img]);
n_iter=[0]

while n_iter[0] <= max_iter:

    def closure():
        optimizer.zero_grad()
        out = vgg(opt_img, loss_layers)
        layer_losses = [weights[a] * loss_fns[a](A, targets[a]) for a,A in enumerate(out)]
        loss = sum(layer_losses)
        loss.backward()
        n_iter[0]+=1
        #print loss
        if n_iter[0]%show_iter == (show_iter-1):
            print('Iteration: %d, loss: %f'%(n_iter[0]+1, loss.data[0]))
#             print([loss_layers[li] + ': ' +  str(l.data[0]) for li,l in enumerate(layer_losses)]) #loss of each layer
        return loss
    
    optimizer.step(closure)
    
#display result
out_img = postp(opt_img.data[0].cpu().squeeze())
imshow(out_img)
gcf().set_size_inches(10,10)
# Out:
# Iteration: 2, loss: 226255808.000000
# Iteration: 4, loss: 48566472704.000000
# Iteration: 6, loss: 95469728.000000
# Iteration: 8, loss: 34478416.000000
# Iteration: 10, loss: 19319828.000000
# Iteration: 12, loss: 11856598.000000
# Iteration: 14, loss: 8031176.500000
# Iteration: 16, loss: 6707832.500000
# Iteration: 18, loss: 5581750.500000
# Iteration: 20, loss: 4677458.500000
# Iteration: 22, loss: 4000095.250000
# Iteration: 24, loss: 3399896.000000
# Iteration: 26, loss: 3093977.500000
# Iteration: 28, loss: 2874262.500000
# Iteration: 30, loss: 2480661.250000
# Iteration: 32, loss: 2199891.000000
# Iteration: 34, loss: 1988821.375000
# Iteration: 36, loss: 1849646.250000
# Iteration: 38, loss: 1682300.000000
# Iteration: 40, loss: 1552341.750000
# Iteration: 42, loss: 1453504.750000
# Iteration: 44, loss: 1515987.750000
# Iteration: 46, loss: 1306457.500000
# Iteration: 48, loss: 1252743.000000
# Iteration: 50, loss: 1173291.250000
# Iteration: 52, loss: 1114553.875000
# Iteration: 54, loss: 1070945.500000
# Iteration: 56, loss: 1037255.500000
# Iteration: 58, loss: 1000091.125000
# Iteration: 60, loss: 969733.250000

# %%
out_img = postp(opt_img.data[0].cpu().squeeze())
imshow(out_img)
gcf().set_size_inches(10,10)
